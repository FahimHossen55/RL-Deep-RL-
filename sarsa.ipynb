# %% [markdown]
# # **SARSA**
#
# - SARSA is an on policy , model free reinfofcement leaning algorithm used to a learn a policy for an agent in an a=environment. it is a particularly suited for problems where the agent interects with environment over multiple time steps, and its goal is to lean=rn a policy that maximizes the expected cumulative reward.
